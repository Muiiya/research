# %% [markdown]
# # 1) 파일 불러오기

# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-1.8.2-cp37-cp37m-manylinux1_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 8.3 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.22.2.post1)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading statsmodels-0.12.2-cp37-cp37m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 38.5 MB/s
# Requirement already satisfied: numpy~=1.19.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.23)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.2.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Installing collected packages: statsmodels, pmdarima
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed pmdarima-1.8.2 statsmodels-0.12.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import os

# %%
raw_csv_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/SCPh1_005930.csv',sep=',')

df_comp = raw_csv_data.copy()

df_comp
# Out:
#            Date   Open   High    Low  Close    Volume
# 0    2019-07-18  46450  46450  45650  46100   5143554
# 1    2019-07-19  46650  46950  46600  46800   8819393
# 2    2019-07-22  46800  47300  46600  47200   9009109
# 3    2019-07-23  47350  47550  47050  47300   9061381
# 4    2019-07-24  47100  47150  46250  46400   8756522
# ..          ...    ...    ...    ...    ...       ...
# 490  2021-07-12  79900  80000  79500  79700   9768108
# 491  2021-07-13  80000  80200  79800  79800   9863450
# 492  2021-07-14  79400  79600  79100  79500  11575636
# 493  2021-07-15  79800  80600  79500  80600  13766279
# 494  2021-07-16  80100  80100  79500  79800  10859399
#
# [495 rows x 6 columns]

# %%
df_comp.Date.describe()
# Out:
# count            495
# unique           495
# top       2020-10-21
# freq               1
# Name: Date, dtype: object

# %%
# Date가 더 이상 텍스트가 아닌 실제 시간으로 저장된다.

df_comp.Date = pd.to_datetime(df_comp.Date, dayfirst = True)

df_comp.head()
# Out:
#         Date   Open   High    Low  Close   Volume
# 0 2019-07-18  46450  46450  45650  46100  5143554
# 1 2019-07-19  46650  46950  46600  46800  8819393
# 2 2019-07-22  46800  47300  46600  47200  9009109
# 3 2019-07-23  47350  47550  47050  47300  9061381
# 4 2019-07-24  47100  47150  46250  46400  8756522

# %%
df_comp.Date.describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
# count                     495
# unique                    495
# top       2020-04-13 00:00:00
# freq                        1
# first     2019-07-18 00:00:00
# last      2021-07-16 00:00:00
# Name: Date, dtype: object

# %% [markdown]
# #2) 시계열 데이터를 전처리할 때 인덱스를 설정한다

# %%
df_comp.set_index('Date', inplace=True)

df_comp.head()
# Out:
#              Open   High    Low  Close   Volume
# Date
# 2019-07-18  46450  46450  45650  46100  5143554
# 2019-07-19  46650  46950  46600  46800  8819393
# 2019-07-22  46800  47300  46600  47200  9009109
# 2019-07-23  47350  47550  47050  47300  9061381
# 2019-07-24  47100  47150  46250  46400  8756522

# %%
#business day(휴일을 제외한 평일)을 기준으로 시계열 데이터를 만든다 

df_comp = df_comp.asfreq('b')

df_comp.head()
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2019-07-18  46450.0  46450.0  45650.0  46100.0  5143554.0
# 2019-07-19  46650.0  46950.0  46600.0  46800.0  8819393.0
# 2019-07-22  46800.0  47300.0  46600.0  47200.0  9009109.0
# 2019-07-23  47350.0  47550.0  47050.0  47300.0  9061381.0
# 2019-07-24  47100.0  47150.0  46250.0  46400.0  8756522.0

# %%
# isna()는 누락된 데이터가 있는지 여부에 따라 집합의 모든 항목에 대해 'True'와 'False'가 표시된다.

df_comp.isna()
# Out:
#              Open   High    Low  Close  Volume
# Date
# 2019-07-18  False  False  False  False   False
# 2019-07-19  False  False  False  False   False
# 2019-07-22  False  False  False  False   False
# 2019-07-23  False  False  False  False   False
# 2019-07-24  False  False  False  False   False
# ...           ...    ...    ...    ...     ...
# 2021-07-12  False  False  False  False   False
# 2021-07-13  False  False  False  False   False
# 2021-07-14  False  False  False  False   False
# 2021-07-15  False  False  False  False   False
# 2021-07-16  False  False  False  False   False
#
# [522 rows x 5 columns]

# %% [markdown]
# Business day 기준으로 바뀌게 되면 NA값이 발생하게 됩니다. 따라서 이 NA값을 처리하는 방안에 대해서 정리해보겠습니다.Pandas에서는 fillna함수를 지원해줍니다. fillna 함수에 간단히 활용할 수 있는 method가 fill과 bfill이 있습니다. ffill은 앞 방향으로 채워주는 것이고 bfill은 뒷 방향으로 채워주는 것입니다. 예를 들어 ffill을 활용하게 되면 2019-12-25를 채우기 위해서 2019-12-24 데이터를 활용하는 것이고 bfill을 활용하게 되면 2019-12-25를 채우기 위해서 2019-12-26을 이용하는 식입니다.

# %%
df_comp.isna().sum()
# Out:
# Open      27
# High      27
# Low       27
# Close     27
# Volume    27
# dtype: int64

# %%
#누락된 요소를 바로 직전 데이터의 값을 가져와서 채운다

df_comp=df_comp.fillna(method='ffill')

df_comp.isna().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
## Plotting
df_comp.Close.plot(title = "Samsung Price")

# %%
scipy.stats.probplot(df_comp.Close, plot = plt)
plt.show()

# %%
df_comp
# Out:
#                Open     High      Low    Close      Volume
# Date
# 2019-07-18  46450.0  46450.0  45650.0  46100.0   5143554.0
# 2019-07-19  46650.0  46950.0  46600.0  46800.0   8819393.0
# 2019-07-22  46800.0  47300.0  46600.0  47200.0   9009109.0
# 2019-07-23  47350.0  47550.0  47050.0  47300.0   9061381.0
# 2019-07-24  47100.0  47150.0  46250.0  46400.0   8756522.0
# ...             ...      ...      ...      ...         ...
# 2021-07-12  79900.0  80000.0  79500.0  79700.0   9768108.0
# 2021-07-13  80000.0  80200.0  79800.0  79800.0   9863450.0
# 2021-07-14  79400.0  79600.0  79100.0  79500.0  11575636.0
# 2021-07-15  79800.0  80600.0  79500.0  80600.0  13766279.0
# 2021-07-16  80100.0  80100.0  79500.0  79800.0  10859399.0
#
# [522 rows x 5 columns]

# %%
#busniss 기준 휴일 빼고 꽉 채웠는데 1분 기준으로 다시 늘린다.

df_comp = df_comp.asfreq('h')

df_comp.head()
# Out:
#                         Open     High      Low    Close     Volume
# Date
# 2019-07-18 00:00:00  46450.0  46450.0  45650.0  46100.0  5143554.0
# 2019-07-18 01:00:00      NaN      NaN      NaN      NaN        NaN
# 2019-07-18 02:00:00      NaN      NaN      NaN      NaN        NaN
# 2019-07-18 03:00:00      NaN      NaN      NaN      NaN        NaN
# 2019-07-18 04:00:00      NaN      NaN      NaN      NaN        NaN

# %%
df_comp.isna().sum()
# Out:
# Open      16975
# High      16975
# Low       16975
# Close     16975
# Volume    16975
# dtype: int64

# %%
df_comp=df_comp.fillna(method='ffill')

df_comp.isna().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
# b, 1m 기준으로 새로 제작한 시계열이다.
# 그러나 인포머 형식에 맞춰주어야 한다.

df_comp
# Out:
#                         Open     High      Low    Close      Volume
# Date
# 2019-07-18 00:00:00  46450.0  46450.0  45650.0  46100.0   5143554.0
# 2019-07-18 01:00:00  46450.0  46450.0  45650.0  46100.0   5143554.0
# 2019-07-18 02:00:00  46450.0  46450.0  45650.0  46100.0   5143554.0
# 2019-07-18 03:00:00  46450.0  46450.0  45650.0  46100.0   5143554.0
# 2019-07-18 04:00:00  46450.0  46450.0  45650.0  46100.0   5143554.0
# ...                      ...      ...      ...      ...         ...
# 2021-07-15 20:00:00  79800.0  80600.0  79500.0  80600.0  13766279.0
# 2021-07-15 21:00:00  79800.0  80600.0  79500.0  80600.0  13766279.0
# 2021-07-15 22:00:00  79800.0  80600.0  79500.0  80600.0  13766279.0
# 2021-07-15 23:00:00  79800.0  80600.0  79500.0  80600.0  13766279.0
# 2021-07-16 00:00:00  80100.0  80100.0  79500.0  79800.0  10859399.0
#
# [17497 rows x 5 columns]

# %%
df_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17497 entries, 2019-07-18 00:00:00 to 2021-07-16 00:00:00
# Freq: H
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    17497 non-null  float64
#  1   High    17497 non-null  float64
#  2   Low     17497 non-null  float64
#  3   Close   17497 non-null  float64
#  4   Volume  17497 non-null  float64
# dtypes: float64(5)
# memory usage: 820.2 KB

# %% [markdown]
# #3)인덱스를 다시 리셋하여 정수로 된 디폴트 인덱스로 바꾼다

# %%
# reset_index()를 쓰면 인덱스를 보통의 자료열로 바꿀 수도 있다. 데이터 프레임의 인덱스는 정수로 된 디폴트 인덱스로 바뀐다.

df_pre=df_comp.reset_index()

df_pre
# Out:
#                      Date     Open     High      Low    Close      Volume
# 0     2019-07-18 00:00:00  46450.0  46450.0  45650.0  46100.0   5143554.0
# 1     2019-07-18 01:00:00  46450.0  46450.0  45650.0  46100.0   5143554.0
# 2     2019-07-18 02:00:00  46450.0  46450.0  45650.0  46100.0   5143554.0
# 3     2019-07-18 03:00:00  46450.0  46450.0  45650.0  46100.0   5143554.0
# 4     2019-07-18 04:00:00  46450.0  46450.0  45650.0  46100.0   5143554.0
# ...                   ...      ...      ...      ...      ...         ...
# 17492 2021-07-15 20:00:00  79800.0  80600.0  79500.0  80600.0  13766279.0
# 17493 2021-07-15 21:00:00  79800.0  80600.0  79500.0  80600.0  13766279.0
# 17494 2021-07-15 22:00:00  79800.0  80600.0  79500.0  80600.0  13766279.0
# 17495 2021-07-15 23:00:00  79800.0  80600.0  79500.0  80600.0  13766279.0
# 17496 2021-07-16 00:00:00  80100.0  80100.0  79500.0  79800.0  10859399.0
#
# [17497 rows x 6 columns]

# %%
#일단 데이터타임인덱스를 없애는데 성공했고, 
#인포머처럼 바꾸려면 date를 object로, float64를 int64로 변형시켜주어야 한다.

df_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17497 entries, 0 to 17496
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    17497 non-null  datetime64[ns]
#  1   Open    17497 non-null  float64
#  2   High    17497 non-null  float64
#  3   Low     17497 non-null  float64
#  4   Close   17497 non-null  float64
#  5   Volume  17497 non-null  float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 820.3 KB

# %%
#datetime64를 object로 변환시킨다.

from datetime import datetime
def convert_datetime(dt):
    return datetime.strftime(dt, '%Y-%m-%d %H:%M-%S')

df_pre['Date']= df_pre['Date'].apply(convert_datetime)

df_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17497 entries, 0 to 17496
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    17497 non-null  object
#  1   Open    17497 non-null  float64
#  2   High    17497 non-null  float64
#  3   Low     17497 non-null  float64
#  4   Close   17497 non-null  float64
#  5   Volume  17497 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 820.3+ KB

# %%
# open, high, low, close, volume을 int64로 변환시켜주어야 한다.

df_pre[['Open','High','Low','Close','Volume']]=df_pre[['Open','High','Low','Close','Volume']].astype('int64')

df_pre
# Out:
#                       Date   Open   High    Low  Close    Volume
# 0      2019-07-18 00:00-00  46450  46450  45650  46100   5143554
# 1      2019-07-18 01:00-00  46450  46450  45650  46100   5143554
# 2      2019-07-18 02:00-00  46450  46450  45650  46100   5143554
# 3      2019-07-18 03:00-00  46450  46450  45650  46100   5143554
# 4      2019-07-18 04:00-00  46450  46450  45650  46100   5143554
# ...                    ...    ...    ...    ...    ...       ...
# 17492  2021-07-15 20:00-00  79800  80600  79500  80600  13766279
# 17493  2021-07-15 21:00-00  79800  80600  79500  80600  13766279
# 17494  2021-07-15 22:00-00  79800  80600  79500  80600  13766279
# 17495  2021-07-15 23:00-00  79800  80600  79500  80600  13766279
# 17496  2021-07-16 00:00-00  80100  80100  79500  79800  10859399
#
# [17497 rows x 6 columns]

# %%
df_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17497 entries, 0 to 17496
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    17497 non-null  object
#  1   Open    17497 non-null  int64
#  2   High    17497 non-null  int64
#  3   Low     17497 non-null  int64
#  4   Close   17497 non-null  int64
#  5   Volume  17497 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 820.3+ KB

# %% [markdown]
# # 5) SCPh1_1B를 저장하기

# %%
df_pre.to_csv('/content/drive/MyDrive/Colab Notebooks/bETTh1.csv')

# %%
# !git clone https://github.com/zhouhaoyi/Informer2020.git
# !git clone https://github.com/Muiiya/research.git
# !ls
# Out:
# Cloning into 'Informer2020'...
# remote: Enumerating objects: 525, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 525 (delta 1), reused 3 (delta 1), pack-reused 517
# Receiving objects: 100% (525/525), 6.47 MiB | 21.04 MiB/s, done.
# Resolving deltas: 100% (298/298), done.
# Cloning into 'research'...
# remote: Enumerating objects: 501, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 501 (delta 2), reused 0 (delta 0), pack-reused 491
# Receiving objects: 100% (501/501), 66.61 MiB | 11.80 MiB/s, done.
# Resolving deltas: 100% (184/184), done.
# drive  Informer2020  research  sample_data

# %%
import sys
if not 'Informer2020' in sys.path:
    sys.path += ['Informer2020']

# %%
# !pip install -r ./Informer2020/requirements.txt

# %%
from utils.tools import dotdict
from exp.exp_informer import Exp_Informer
import torch

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import os

# %%
args = dotdict()

args.model = 'informer' # model of experiment, options: [informer, informerstack, informerlight(TBD)]

args.data = 'ETTh1' # data
args.root_path = './research/Dataset/' # root path of data file
args.data_path = 'ETTh1.csv' # data file
args.features = 'MS' # forecasting task, options:[M, S, MS]; M:multivariate predict multivariate, S:univariate predict univariate, MS:multivariate predict univariate
args.target = 'Close' # target feature in S or MS task
args.freq = 'b' # freq for time features encoding, options:[s:secondly, t:minutely, h:hourly, d:daily, b:business days, w:weekly, m:monthly], you can also use more detailed freq like 15min or 3h
args.checkpoints = './informer_checkpoints' # location of model checkpoints

args.seq_len = 96 # input sequence length of Informer encoder
args.label_len = 48 # start token length of Informer decoder
args.pred_len = 24 # prediction sequence length
# Informer decoder input: concat[start token series(label_len), zero padding series(pred_len)]

args.enc_in = 5 # encoder input size
args.dec_in = 5 # decoder input size
args.c_out = 1 # output size
args.factor = 5 # probsparse attn factor
args.d_model = 512 # dimension of model
args.n_heads = 8 # num of heads
args.e_layers = 2 # num of encoder layers
args.d_layers = 1 # num of decoder layers
args.d_ff = 2048 # dimension of fcn in model
args.dropout = 0.05 # dropout
args.attn = 'prob' # attention used in encoder, options:[prob, full]
args.embed = 'timeF' # time features encoding, options:[timeF, fixed, learned]
args.activation = 'gelu' # activation
args.distil = True # whether to use distilling in encoder
args.output_attention = False # whether to output attention in ecoder
args.mix = True
args.padding = 0
args.freq = 'b'

args.batch_size = 16 # 배치사이즈
args.learning_rate = 0.0001
args.loss = 'mse'
args.lradj = 'type1'
args.use_amp = False # whether to use automatic mixed precision training

args.num_workers = 0
args.itr = 1
args.train_epochs = 50 # 에포크 수
args.patience = 50  # early stopping 횟수
args.des = 'exp'

args.use_gpu = True if torch.cuda.is_available() else False
args.gpu = 0

args.use_multi_gpu = False
args.devices = '0,1,2,3'

# %%
setting = '{}_{}_ft{}_sl{}_ll{}_pl{}_dm{}_nh{}_el{}_dl{}_df{}_at{}_fc{}_eb{}_dt{}_{}_{}'\
          .format(args.model, args.data, args.features, args.seq_len, args.label_len, args.pred_len, 
                  args.d_model, args.n_heads, args.e_layers, args.d_layers, args.d_ff, 
                  args.attn, args.factor, args.embed, args.distil, args.des, "electr1day")

exp = Exp_Informer(args)
# Out:
# Use GPU: cuda:0

# %%
print('>>>>>>>Initiating model training : {}>>>>>>>>>>>>>>>>>>>'.format(setting))
exp.train(setting)

print('>>>>>>>Initiating model testing : {}<<<<<<<<<<<<<<<<<'.format(setting))
exp.test(setting)

# train/val/test = 0.6:0.2:0.2

torch.cuda.empty_cache()
# Out:
# >>>>>>>Initiating model training : informer_ETTh1_ftMS_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_electr1day>>>>>>>>>>>>>>>>>>>
# train 8521
# val 2857
# test 2857
# 	iters: 100, epoch: 1 | loss: 0.1831040
# 	speed: 0.0432s/iter; left time: 1145.0613s
# 	iters: 200, epoch: 1 | loss: 0.1653464
# 	speed: 0.0391s/iter; left time: 1033.1378s
# 	iters: 300, epoch: 1 | loss: 0.2190045
# 	speed: 0.0394s/iter; left time: 1036.9581s
# 	iters: 400, epoch: 1 | loss: 0.1448412
# 	speed: 0.0401s/iter; left time: 1051.4032s
# 	iters: 500, epoch: 1 | loss: 0.1274747
# 	speed: 0.0399s/iter; left time: 1040.8717s
# Epoch: 1 cost time: 21.504699230194092
# Epoch: 1, Steps: 532 | Train Loss: 0.2202758 Vali Loss: 0.2025217 Test Loss: 2.0837862
# Validation loss decreased (inf --> 0.202522).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 100, epoch: 2 | loss: 0.1022361
# 	speed: 0.1057s/iter; left time: 2746.1168s
# 	iters: 200, epoch: 2 | loss: 0.1840921
# 	speed: 0.0405s/iter; left time: 1047.2483s
# 	iters: 300, epoch: 2 | loss: 0.0644825
# 	speed: 0.0405s/iter; left time: 1044.9327s
# 	iters: 400, epoch: 2 | loss: 0.0999726
# 	speed: 0.0406s/iter; left time: 1041.3055s
# 	iters: 500, epoch: 2 | loss: 0.0594493
# 	speed: 0.0406s/iter; left time: 1037.2575s
# Epoch: 2 cost time: 21.5650851726532
# Epoch: 2, Steps: 532 | Train Loss: 0.1123909 Vali Loss: 0.2022807 Test Loss: 2.0706370
# Validation loss decreased (0.202522 --> 0.202281).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 100, epoch: 3 | loss: 0.
# EarlyStopping counter: 4 out of 50
# Updating learning rate to 3.125e-06
# 	iters: 100, epoch: 7 | loss: 0.0245786
# 	speed: 0.1068s/iter; left time: 2488.5678s
# 	iters: 200, epoch: 7 | loss: 0.0565210
# 	speed: 0.0411s/iter; left time: 954.7603s
# 	iters: 300, epoch: 7 | loss: 0.0211608
# 	speed: 0.0407s/iter; left time: 940.9673s
# 	iters: 400, epoch: 7 | loss: 0.0329454
# 	speed: 0.0406s/iter; left time: 933.4839s
# 	iters: 500, epoch: 7 | loss: 0.0488616
# 	speed: 0.0408s/iter; left time: 935.1626s
# Epoch: 7 cost time: 21.68251895904541
# Epoch: 7, Steps: 532 | Train Loss: 0.0411612 Vali Loss: 0.2342662 Test Loss: 2.2064521
# EarlyStopping counter: 5 out of 50
# Updating learning rate to 1.5625e-06
# 	iters: 100, epoch: 8 | loss: 0.0318036
# 	speed: 0.1072s/iter; left time: 2440.6959s
# 	iters: 200, epoch: 8 | loss: 0.0303554
# 	speed: 0.0414s/iter; left time: 937.8477s
# 	iters: 300, epoch: 8 | loss: 0.0173738
# 	speed: 0.0412s/iter; left time: 929.9267s
# 	iters: 400, epoch: 8 | loss: 0.0282343
# 	speed: 0.0414s/iter; left time: 931.6019s
# 	iters: 500, epoch: 8 | loss: 0.0297787
# 	speed: 0.0419s/iter; left time: 938.0468s
# Epoch: 8 cost time: 22.028985500335693
# Epoch: 8, Steps: 532 | Train Loss: 0.0403165 Vali Loss: 0.2335703 Test Loss: 2.2552164
# EarlyStopping counter: 6 out of 50
# Updating learning rate to 7.8125e-07
# 	iters: 100, epoch: 9 | loss: 0.0256264
# 	speed: 0.1085s/iter; left time: 2414.2219s
# 	iters: 200, epoch: 9 | loss: 0.0416106
# 	speed: 0.0416s/iter; left time: 921.0290s
# 	iters: 300, epoch: 9 | loss: 0.0392234
# 	speed: 0.0413s/iter; left time: 910.8203s
# 	iters: 400, epoch: 9 | loss: 0.0207956
# 	speed: 0.0408s/iter; left time: 896.0542s
# 	iters: 500, epoch: 9 | loss: 0.0357285
# 	speed: 0.0407s/iter; left time: 889.4277s
# Epoch: 9 cost time: 21.915425539016724
# Epoch: 9, Steps: 532 | Train Loss: 0.0393814 Vali Loss: 0.2323126 Test Loss: 2.2573318
# EarlyStopping counter: 7 out of 50
# Updating learning rate to 3.90625e-07
# 	iters: 100, epoch: 10 | loss: 0.0269016
# 	speed: 0.1067s/iter; left time: 2317.1717s
# 	iters: 200, epoch: 10 | loss: 0.0200908
# 	speed: 0.0409s/iter; left time: 884.0844s
# 	iters: 300, epoch: 10 | loss: 0.0360523
# 	speed: 0.0409s/iter; left time: 880.2259s
# 	iters: 400, epoch: 10 | loss: 0.0421181
# 	speed: 0.0408s/iter; left time: 874.3150s
# 	iters: 500, epoch: 10 | loss: 0.0442563
# 	speed: 0.0411s/iter; left time: 875.7447s
# Epoch: 10 cost time: 21.778194189071655
# Epoch: 10, Steps: 532 | Train Loss: 0.0388384 Vali Loss: 0.2381489 Test Loss: 2.2725217
# EarlyStopping counter: 8 out of 50
# Updating learning rate to 1.953125e-07
# 	speed: 0.1067s/iter; left time: 2032.9491s
# 	iters: 200, epoch: 15 | loss: 0.0653683
# 	speed: 0.0406s/iter; left time: 769.2838s
# 	iters: 300, epoch: 15 | loss: 0.0173211
# 	speed: 0.0406s/iter; left time: 765.4998s
# 	iters: 400, epoch: 15 | loss: 0.0611815
# 	speed: 0.0408s/iter; left time: 764.6901s
# 	iters: 500, epoch: 15 | loss: 0.0763252
# 	speed: 0.0408s/iter; left time: 760.2732s
# Epoch: 15 cost time: 21.679325819015503
# Epoch: 15, Steps: 532 | Train Loss: 0.0387506 Vali Loss: 0.2354968 Test Loss: 2.2489481
# EarlyStopping counter: 13 out of 50
# Updating learning rate to 6.103515625e-09
# 	iters: 100, epoch: 16 | loss: 0.0315226
# 	speed: 0.1076s/iter; left time: 1993.1113s
# 	iters: 200, epoch: 16 | loss: 0.0754132
# 	speed: 0.0410s/iter; left time: 755.3325s
# 	iters: 300, epoch: 16 | loss: 0.0394160
# 	speed: 0.0411s/iter; left time: 753.1792s
# 	iters: 400, epoch: 16 | loss: 0.0444601
# 	speed: 0.0411s/iter; left time: 749.2365s
# 	iters: 500, epoch: 16 | loss: 0.0306131
# 	speed: 0.0411s/iter; left time: 744.9316s
# Epoch: 16 cost time: 21.857813835144043
# Epoch: 16, Steps: 532 | Train Loss: 0.0390390 Vali Loss: 0.2345725 Test Loss: 2.2517080
# EarlyStopping counter: 14 out of 50
# Updating learning rate to 3.0517578125e-09
# 	iters: 100, epoch: 17 | loss: 0.0298111
# 	speed: 0.1072s/iter; left time: 1927.9224s
# 	iters: 200, epoch: 17 | loss: 0.0436488
# 	speed: 0.0413s/iter; left time: 739.4353s
# 	iters: 300, epoch: 17 | loss: 0.0476060
# 	speed: 0.0413s/iter; left time: 735.4485s
# 	iters: 400, epoch: 17 | loss: 0.0604447
# 	speed: 0.0413s/iter; left time: 731.3918s
# 	iters: 500, epoch: 17 | loss: 0.0244384
# 	speed: 0.0410s/iter; left time: 721.4525s
# Epoch: 17 cost time: 21.95711660385132
# Epoch: 17, Steps: 532 | Train Loss: 0.0390486 Vali Loss: 0.2355835 Test Loss: 2.2627633
# EarlyStopping counter: 15 out of 50
# Updating learning rate to 1.52587890625e-09
# 	iters: 100, epoch: 18 | loss: 0.0277706
# 	speed: 0.1069s/iter; left time: 1865.4448s
# 	iters: 200, epoch: 18 | loss: 0.0743501
# 	speed: 0.0407s/iter; left time: 705.5900s
# 	iters: 300, epoch: 18 | loss: 0.1017570
# 	speed: 0.0405s/iter; left time: 699.2602s
# 	iters: 400, epoch: 18 | loss: 0.0269826
# 	speed: 0.0405s/iter; left time: 694.5231s
# 	iters: 500, epoch: 18 | loss: 0.0250879
# 	speed: 0.0405s/iter; left time: 691.4653s
# Epoch: 18 cost time: 21.58968448638916
# Epoch: 18, Steps: 532 | Train Loss: 0.0388600 Vali Loss: 0.2357099 Test Loss: 2.2548008
# EarlyStopping counter: 16 out of 50
# Updating learning rate to 7.62939453125e-10
# 	iters: 100, epoch: 19 | loss: 0.0488569
# 	speed: 0.1063s/iter; left time: 1798.8855s
# 	iters: 200, epoch: 19 | loss: 0.0155661
# 	speed: 0.0409s/iter; left time: 688.3869s
# 	iters: 300, epoch: 19 | loss: 0.0435967
# 	speed: 0.0409s/iter; left time: 684.5982s
# 	iters: 400, epoch: 19 | loss: 0.0475695
# 	speed: 0.0414s/iter; left time: 687.5987s
# 	iters: 500, epoch: 19 | loss: 0.0470012
# 	speed: 0.0413s/iter; left time: 682.5559s
# Epoch: 19 cost time: 21.84220552444458
# Epoch: 19, Steps: 532 | Train Loss: 0.0387168 Vali Loss: 0.2358785 Test Loss: 2.2505832
# EarlyStopping counter: 17 out of 50
# Updating learning rate to 3.814697265625e-10
# 	iters: 100, epoch: 20 | loss: 0.0538560
# 	speed: 0.1080s/iter; left time: 1770.0076s
# 	iters: 200, epoch: 20 | loss: 0.0278359
# 	speed: 0.0412s/iter; left time: 671.1536s
# 	iters: 300, epoch: 20 | loss: 0.0339081
# 	speed: 0.0408s/iter; left time: 661.0445s
# 	iters: 400, epoch: 20 | loss: 0.0389515
# 	speed: 0.0408s/iter; left time: 656.0430s
# 	iters: 500, epoch: 20 | loss: 0.0384326
# 	speed: 0.0405s/iter; left time: 648.0090s
# Epoch: 20 cost time: 21.76312279701233
# Epoch: 20, Steps: 532 | Train Loss: 0.0388435 Vali Loss: 0.2327824 Test Loss: 2.2233605
# EarlyStopping counter: 18 out of 50
# Updating learning rate to 1.9073486328125e-10
# 	iters: 100, epoch: 21 | loss: 0.0425142
# 	speed: 0.1063s/iter; left time: 1685.7358s
# 	iters: 200, epoch: 21 | loss: 0.0362452
# 	speed: 0.0405s/iter; left time: 638.2359s
# 	iters: 300, epoch: 21 | loss: 0.0518820
# 	speed: 0.0407s/iter; left time: 637.6642s
# 	iters: 400, epoch: 21 | loss: 0.0309107
# 	speed: 0.0407s/iter; left time: 633.5217s
# 	iters: 500, epoch: 21 | loss: 0.0453842
# 	speed: 0.0405s/iter; left time: 626.4527s
# Epoch: 21 cost time: 21.602335214614868
# Epoch: 21, Steps: 532 | Train Loss: 0.0389471 Vali Loss: 0.2358929 Test Loss: 2.2457125
# EarlyStopping counter: 19 out of 50
# Updating learning rate to 9.5367431640625e-11
# 	iters: 100, epoch: 22 | loss: 0.0574815
# 	speed: 0.1076s/iter; left time: 1649.2982s
# 	iters: 200, epoch: 22 | loss: 0.0487220
# 	speed: 0.0413s/iter; left time: 628.8903s
# 	iters: 300, epoch: 22 | loss: 0.0240913
# 	speed: 0.0412s/iter; left time: 623.7676s
# 	iters: 400, epoch: 22 | loss: 0.0193851
# 	speed: 0.0411s/iter; left time: 618.3655s
# 	iters: 500, epoch: 22 | loss: 0.0354540
# 	speed: 0.0412s/iter; left time: 615.1961s
# Epoch: 22 cost time: 21.937744855880737
# Epoch: 22, Steps: 532 | Train Loss: 0.0388659 Vali Loss: 0.2350847 Test Loss: 2.2553985
# EarlyStopping counter: 20 out of 50
# Updating learning rate to 4.76837158203125e-11
# 	iters: 100, epoch: 23 | loss: 0.0598447
# 	speed: 0.1066s/iter; left time: 1577.8890s
# 	iters: 200, epoch: 27 | loss: 0.0425222
# 	speed: 0.0414s/iter; left time: 520.6211s
# 	iters: 300, epoch: 27 | loss: 0.0328184
# 	speed: 0.0415s/iter; left time: 517.4731s
# 	iters: 400, epoch: 27 | loss: 0.0286221
# 	speed: 0.0416s/iter; left time: 514.3383s
# 	iters: 500, epoch: 27 | loss: 0.0621545
# 	speed: 0.0407s/iter; left time: 498.9177s
# Epoch: 27 cost time: 21.974181652069092
# Epoch: 27, Steps: 532 | Train Loss: 0.0389115 Vali Loss: 0.2346965 Test Loss: 2.2484577
# EarlyStopping counter: 25 out of 50
# Updating learning rate to 1.4901161193847657e-12
# 	iters: 100, epoch: 28 | loss: 0.0445047
# 	speed: 0.1076s/iter; left time: 1306.0344s
# 	iters: 200, epoch: 28 | loss: 0.0437797
# 	speed: 0.0414s/iter; left time: 498.0355s
# 	iters: 300, epoch: 28 | loss: 0.0353065
# 	speed: 0.0414s/iter; left time: 494.5782s
# 	iters: 400, epoch: 28 | loss: 0.0469876
# 	speed: 0.0414s/iter; left time: 489.8339s
# 	iters: 500, epoch: 28 | loss: 0.0381898
# 	speed: 0.0415s/iter; left time: 487.3836s
# Epoch: 28 cost time: 22.02262020111084
# Epoch: 28, Steps: 532 | Train Loss: 0.0388787 Vali Loss: 0.2334385 Test Loss: 2.2310688
# EarlyStopping counter: 26 out of 50
# Updating learning rate to 7.450580596923828e-13
# 	iters: 100, epoch: 29 | loss: 0.0281898
# 	speed: 0.1069s/iter; left time: 1240.2775s
# 	iters: 200, epoch: 29 | loss: 0.0934984
# 	speed: 0.0406s/iter; left time: 467.2448s
# 	iters: 300, epoch: 29 | loss: 0.0371297
# 	speed: 0.0412s/iter; left time: 469.8933s
# 	iters: 400, epoch: 29 | loss: 0.0449423
# 	speed: 0.0406s/iter; left time: 458.4556s
# 	iters: 500, epoch: 29 | loss: 0.0504138
# 	speed: 0.0405s/iter; left time: 454.1505s
# Epoch: 29 cost time: 21.679251194000244
# Epoch: 29, Steps: 532 | Train Loss: 0.0385330 Vali Loss: 0.2354067 Test Loss: 2.2380314
# EarlyStopping counter: 27 out of 50
# Updating learning rate to 3.725290298461914e-13
# 	iters: 100, epoch: 30 | loss: 0.0241942
# 	speed: 0.1067s/iter; left time: 1180.9611s
# 	iters: 200, epoch: 30 | loss: 0.0269271
# 	speed: 0.0406s/iter; left time: 446.0410s
# 	iters: 300, epoch: 30 | loss: 0.0336238
# 	speed: 0.0411s/iter; left time: 446.5210s
# 	iters: 400, epoch: 30 | loss: 0.0176099
# 	speed: 0.0414s/iter; left time: 446.2557s
# 	iters: 500, epoch: 30 | loss: 0.0155078
# 	speed: 0.0415s/iter; left time: 442.9063s
# Epoch: 30 cost time: 21.88157844543457
# Epoch: 30, Steps: 532 | Train Loss: 0.0388833 Vali Loss: 0.2362611 Test Loss: 2.2576261
# EarlyStopping counter: 28 out of 50
# Updating learning rate to 1.862645149230957e-13
# 	iters: 100, epoch: 31 | loss: 0.0269886
# 	speed: 0.1075s/iter; left time: 1133.3123s
# 	iters: 200, epoch: 31 | loss: 0.0289127
# 	iters: 300, epoch: 39 | loss: 0.0500385
# 	speed: 0.0407s/iter; left time: 247.6836s
# 	iters: 400, epoch: 39 | loss: 0.0351727
# 	speed: 0.0405s/iter; left time: 242.2547s
# 	iters: 500, epoch: 39 | loss: 0.0355898
# 	speed: 0.0405s/iter; left time: 238.6266s
# Epoch: 39 cost time: 21.586167573928833
# Epoch: 39, Steps: 532 | Train Loss: 0.0392924 Vali Loss: 0.2351579 Test Loss: 2.2278018
# EarlyStopping counter: 37 out of 50
# Updating learning rate to 3.637978807091713e-16
# 	iters: 100, epoch: 40 | loss: 0.0242057
# 	speed: 0.1065s/iter; left time: 612.4676s
# 	iters: 200, epoch: 40 | loss: 0.0276353
# 	speed: 0.0415s/iter; left time: 234.6091s
# 	iters: 300, epoch: 40 | loss: 0.0327753
# 	speed: 0.0411s/iter; left time: 228.0214s
# 	iters: 400, epoch: 40 | loss: 0.0412631
# 	speed: 0.0414s/iter; left time: 225.7705s
# 	iters: 500, epoch: 40 | loss: 0.0423193
# 	speed: 0.0411s/iter; left time: 219.8595s
# Epoch: 40 cost time: 21.911624670028687
# Epoch: 40, Steps: 532 | Train Loss: 0.0388663 Vali Loss: 0.2353261 Test Loss: 2.2453196
# EarlyStopping counter: 38 out of 50
# Updating learning rate to 1.8189894035458566e-16
# 	iters: 100, epoch: 41 | loss: 0.0532658
# 	speed: 0.1078s/iter; left time: 563.0002s
# 	iters: 200, epoch: 41 | loss: 0.0299785
# 	speed: 0.0405s/iter; left time: 207.5725s
# 	iters: 300, epoch: 41 | loss: 0.0283920
# 	speed: 0.0414s/iter; left time: 208.0569s
# 	iters: 400, epoch: 41 | loss: 0.0241339
# 	speed: 0.0412s/iter; left time: 202.5296s
# 	iters: 500, epoch: 41 | loss: 0.0266291
# 	speed: 0.0413s/iter; left time: 199.2754s
# Epoch: 41 cost time: 21.82929301261902
# Epoch: 41, Steps: 532 | Train Loss: 0.0387618 Vali Loss: 0.2362764 Test Loss: 2.2591531
# EarlyStopping counter: 39 out of 50
# Updating learning rate to 9.094947017729283e-17
# 	iters: 100, epoch: 42 | loss: 0.0706048
# 	speed: 0.1078s/iter; left time: 505.5518s
# 	iters: 200, epoch: 42 | loss: 0.0448099
# 	speed: 0.0411s/iter; left time: 188.6189s
# 	iters: 300, epoch: 42 | loss: 0.0455535
# 	speed: 0.0407s/iter; left time: 182.6973s
# 	iters: 400, epoch: 42 | loss: 0.0649931
# 	speed: 0.0405s/iter; left time: 177.9527s
# 	iters: 500, epoch: 42 | loss: 0.0530221
# 	speed: 0.0412s/iter; left time: 176.6448s
# Epoch: 42 cost time: 21.800044059753418
# Epoch: 42, Steps: 532 | Train Loss: 0.0389432 Vali Loss: 0.2349615 Test Loss: 2.2389750
# EarlyStopping counter: 40 out of 50
# Updating learning rate to 4.5474735088646414e-17
# 	iters: 100, epoch: 43 | loss: 0.0393529
# 	speed: 0.1066s/iter; left time: 443.2049s
# 	iters: 200, epoch: 43 | loss: 0.0413381
# 	speed: 0.0407s/iter; left time: 165.0704s
# 	speed: 0.0410s/iter; left time: 74.9291s
# 	iters: 400, epoch: 47 | loss: 0.0275034
# 	speed: 0.0406s/iter; left time: 70.2479s
# 	iters: 500, epoch: 47 | loss: 0.0183437
# 	speed: 0.0408s/iter; left time: 66.4257s
# Epoch: 47 cost time: 21.721028089523315
# Epoch: 47, Steps: 532 | Train Loss: 0.0388640 Vali Loss: 0.2342717 Test Loss: 2.2346773
# EarlyStopping counter: 45 out of 50
# Updating learning rate to 1.4210854715202004e-18
# 	iters: 100, epoch: 48 | loss: 0.0314342
# 	speed: 0.1070s/iter; left time: 160.2269s
# 	iters: 200, epoch: 48 | loss: 0.0279654
# 	speed: 0.0412s/iter; left time: 57.5794s
# 	iters: 300, epoch: 48 | loss: 0.0240341
# 	speed: 0.0414s/iter; left time: 53.7107s
# 	iters: 400, epoch: 48 | loss: 0.0228576
# 	speed: 0.0411s/iter; left time: 49.1926s
# 	iters: 500, epoch: 48 | loss: 0.0348414
# 	speed: 0.0414s/iter; left time: 45.3775s
# Epoch: 48 cost time: 21.92330026626587
# Epoch: 48, Steps: 532 | Train Loss: 0.0389729 Vali Loss: 0.2361386 Test Loss: 2.2597227
# EarlyStopping counter: 46 out of 50
# Updating learning rate to 7.105427357601002e-19
# 	iters: 100, epoch: 49 | loss: 0.0460932
# 	speed: 0.1080s/iter; left time: 104.1787s
# 	iters: 200, epoch: 49 | loss: 0.0284675
# 	speed: 0.0413s/iter; left time: 35.7636s
# 	iters: 300, epoch: 49 | loss: 0.0220753
# 	speed: 0.0412s/iter; left time: 31.4952s
# 	iters: 400, epoch: 49 | loss: 0.0525563
# 	speed: 0.0409s/iter; left time: 27.1743s
# 	iters: 500, epoch: 49 | loss: 0.0377817
# 	speed: 0.0409s/iter; left time: 23.1178s
# Epoch: 49 cost time: 21.8757381439209
# Epoch: 49, Steps: 532 | Train Loss: 0.0388357 Vali Loss: 0.2386238 Test Loss: 2.2454076
# EarlyStopping counter: 47 out of 50
# Updating learning rate to 3.552713678800501e-19
# 	iters: 100, epoch: 50 | loss: 0.0281137
# 	speed: 0.1064s/iter; left time: 46.0788s
# 	iters: 200, epoch: 50 | loss: 0.0376785
# 	speed: 0.0406s/iter; left time: 13.5130s
# 	iters: 300, epoch: 50 | loss: 0.0498520
# 	speed: 0.0406s/iter; left time: 9.4581s
# 	iters: 400, epoch: 50 | loss: 0.0405254
# 	speed: 0.0405s/iter; left time: 5.3916s
# 	iters: 500, epoch: 50 | loss: 0.0444191
# 	speed: 0.0407s/iter; left time: 1.3432s
# Epoch: 50 cost time: 21.607505321502686
# Epoch: 50, Steps: 532 | Train Loss: 0.0387129 Vali Loss: 0.2380239 Test Loss: 2.2537556
# EarlyStopping counter: 48 out of 50
# Updating learning rate to 1.7763568394002505e-19
# >>>>>>>Initiating model testing : informer_ETTh1_ftMS_sl96_ll48_pl24_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_exp_electr1day<<<<<<<<<<<<<<<<<
# test 2857
# test shape: (178, 16, 24, 1) (178, 16, 24, 1)
# test shape: (2848, 24, 1) (2848, 24, 1)
# mse:2.071269989013672, mae:1.0741980075836182
