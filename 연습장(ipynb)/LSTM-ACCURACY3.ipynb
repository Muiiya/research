# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os

# %matplotlib inline
warnings.filterwarnings('ignore')

plt.rcParams['font.family'] = 'DejaVu Sans'

# %%
import FinanceDataReader as fdr
samsung = fdr.DataReader('005930')
samsung.tail()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-01-25  87000  89900  86300  89400  27258534  0.029954
# 2021-01-26  88800  89200  86500  86700  33178936 -0.030201
# 2021-01-27  86600  87700  85600  85600  26423070 -0.012687
# 2021-01-28  83200  85600  83200  83700  31859808 -0.022196
# 2021-01-29  84500  85000  82000  82000  36700640 -0.020311

# %%
STOCK_CODE = '005930'

# %%
stock = fdr.DataReader(STOCK_CODE)

# %%
stock.head()
# Out:
#             Open  High   Low  Close  Volume    Change
# Date
# 1997-02-18   996  1028   987   1012  164930       NaN
# 1997-02-19  1013  1024  1004   1023  104330  0.010870
# 1997-02-20  1013  1031   999   1007   88710 -0.015640
# 1997-02-21   996  1004   933    943  143230 -0.063555
# 1997-02-22   933   969   916    966  124900  0.024390

# %%
stock.tail()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-01-25  87000  89900  86300  89400  27258534  0.029954
# 2021-01-26  88800  89200  86500  86700  33178936 -0.030201
# 2021-01-27  86600  87700  85600  85600  26423070 -0.012687
# 2021-01-28  83200  85600  83200  83700  31859808 -0.022196
# 2021-01-29  84500  85000  82000  82000  36700640 -0.020311

# %%
stock.index
# Out:
# DatetimeIndex(['1997-02-18', '1997-02-19', '1997-02-20', '1997-02-21',
#                '1997-02-22', '1997-02-24', '1997-02-25', '1997-02-26',
#                '1997-02-27', '1997-02-28',
#                ...
#                '2021-01-18', '2021-01-19', '2021-01-20', '2021-01-21',
#                '2021-01-22', '2021-01-25', '2021-01-26', '2021-01-27',
#                '2021-01-28', '2021-01-29'],
#               dtype='datetime64[ns]', name='Date', length=6000, freq=None)

# %%
stock['Year'] = stock.index.year
stock['Month'] = stock.index.month
stock['Day'] = stock.index.day

# %%
stock.head()
# Out:
#             Open  High   Low  Close  Volume    Change  Year  Month  Day
# Date
# 1997-02-18   996  1028   987   1012  164930       NaN  1997      2   18
# 1997-02-19  1013  1024  1004   1023  104330  0.010870  1997      2   19
# 1997-02-20  1013  1031   999   1007   88710 -0.015640  1997      2   20
# 1997-02-21   996  1004   933    943  143230 -0.063555  1997      2   21
# 1997-02-22   933   969   916    966  124900  0.024390  1997      2   22

# %%
plt.figure(figsize=(16,9))
sns.lineplot(y=stock['Close'], x=stock.index)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %%
time_steps = [['1990', '2000'],
              ['2000', '2010'],
              ['2010', '2015'],
              ['2015', '2020']]
fig, axes = plt.subplots(2,2)
fig.set_size_inches(16,9)
for i in range(4):
    ax = axes[i//2, i%2]
    df = stock.loc[(stock.index > time_steps[i][0])&(stock.index < time_steps[i][1])]
    sns.lineplot(y=df['Close'], x=df.index, ax=ax)
    ax.set_title(f'{time_steps[i][0]}~{time_steps[i][1]}')
    ax.set_xlabel('time')
    ax.set_ylabel('price')
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scale_cols = ['Open', 'High', 'Low', 'Close', 'Volume']
scaled = scaler.fit_transform(stock[scale_cols])
scaled
# Out:
# array([[0.0110299 , 0.01061983, 0.01102793, 0.00426012, 0.00182634],
#        [0.01121816, 0.01057851, 0.01121788, 0.00438184, 0.00115529],
#        [0.01121816, 0.01065083, 0.01116201, 0.0042048 , 0.00098232],
#        ...,
#        [0.95902547, 0.90599174, 0.95642458, 0.94024764, 0.29259427],
#        [0.9213732 , 0.88429752, 0.92960894, 0.91922366, 0.35279766],
#        [0.93576966, 0.87809917, 0.91620112, 0.90041273, 0.40640232]])

# %%
df = pd.DataFrame(scaled, columns=scale_cols)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('Close',1), df['Close'], test_size=0.2, random_state=0, shuffle=False)

# %%
x_train.shape, y_train.shape
# Out:
# ((4800, 4), (4800,))

# %%
x_test.shape, y_test.shape
# Out:
# ((1200, 4), (1200,))

# %%
x_train
# Out:
#           Open      High       Low    Volume
# 0     0.011030  0.010620  0.011028  0.001826
# 1     0.011218  0.010579  0.011218  0.001155
# 2     0.011218  0.010651  0.011162  0.000982
# 3     0.011030  0.010372  0.010425  0.001586
# 4     0.010332  0.010010  0.010235  0.001383
# ...        ...       ...       ...       ...
# 4795  0.270875  0.252893  0.265028  0.002394
# 4796  0.263123  0.247727  0.263017  0.002031
# 4797  0.267553  0.255372  0.268380  0.003140
# 4798  0.271318  0.258884  0.271732  0.002959
# 4799  0.280620  0.263017  0.279106  0.002405
#
# [4800 rows x 4 columns]

# %%
plt.figure(figsize=(16,9))
plt.plot(y_train)
plt.plot(y_test)

# %%
import tensorflow as tf

# %%
def windowed_dataset(series, window_size, batch_size, shuffle):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    if shuffle:
        ds = ds.shuffle(1000)
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    return ds.batch(batch_size).prefetch(1)

# %%
WINDOW_SIZE = 20
BATCH_SIZE = 32

# %%
train_data = windowed_dataset(y_train, WINDOW_SIZE, BATCH_SIZE, True)
test_data = windowed_dataset(y_test, WINDOW_SIZE, BATCH_SIZE, False)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, Lambda
from tensorflow.keras.losses import Huber, MAPE, MSLE, categorical_crossentropy
from tensorflow.keras.metrics import Accuracy, Mean, Precision
from tensorflow.keras.optimizers import Adam, RMSprop, Optimizer, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

model = Sequential([
    Conv1D(filters=32, kernel_size=5,
          padding="causal",
          activation="relu",
          input_shape=[WINDOW_SIZE, 1]),
    LSTM(16, activation='tanh'),
    Dense(16, activation="relu"),
    Dense(1),
])

# %%
loss = Huber()
model.compile(loss=Huber(), optimizer='rmsprop', metrics=['mse'])

# %%
earlystopping = EarlyStopping(monitor='val_loss', patience=10)
filename = os.path.join('tmp', 'checkpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                            save_weights_only=True,
                            save_best_only=True,
                            monitor='val_loss',
                            verbose=1)

# %%
history = model.fit(train_data,
                   validation_data=(test_data),
                   epochs=50,
                   callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/50
# 150/150 [==============================] - 4s 11ms/step - loss: 6.8386e-05 - mse: 1.3677e-04 - val_loss: 0.0056 - val_mse: 0.0112
#
# Epoch 00001: val_loss improved from inf to 0.00558, saving model to tmp\checkpointer.ckpt
# Epoch 2/50
# 150/150 [==============================] - 1s 7ms/step - loss: 3.0113e-05 - mse: 6.0227e-05 - val_loss: 0.0035 - val_mse: 0.0070
#
# Epoch 00002: val_loss improved from 0.00558 to 0.00351, saving model to tmp\checkpointer.ckpt
# Epoch 3/50
# 150/150 [==============================] - 1s 7ms/step - loss: 2.5223e-05 - mse: 5.0447e-05 - val_loss: 0.0026 - val_mse: 0.0053
#
# Epoch 00003: val_loss improved from 0.00351 to 0.00265, saving model to tmp\checkpointer.ckpt
# Epoch 4/50
# 150/150 [==============================] - 1s 7ms/step - loss: 2.4798e-05 - mse: 4.9595e-05 - val_loss: 0.0032 - val_mse: 0.0064
#
# Epoch 00004: val_loss did not improve from 0.00265
# Epoch 5/50
# 150/150 [==============================] - 1s 7ms/step - loss: 2.3679e-05 - mse: 4.7359e-05 - val_loss: 0.0023 - val_mse: 0.0045
#
# Epoch 00005: val_loss improved from 0.00265 to 0.00227, saving model to tmp\checkpointer.ckpt
# Epoch 6/50
# 150/150 [==============================] - 1s 7ms/step - loss: 2.2433e-05 - mse: 4.4865e-05 - val_loss: 0.0012 - val_mse: 0.0024
#
# Epoch 00006: val_loss improved from 0.00227 to 0.00118, saving model to tmp\checkpointer.ckpt
# Epoch 7/50
# 150/150 [==============================] - 1s 7ms/step - loss: 2.2491e-05 - mse: 4.4981e-05 - val_loss: 0.0033 - val_mse: 0.0066
#
# Epoch 00007: val_loss did not improve from 0.00118
# Epoch 8/50
# 150/150 [==============================] - 1s 7ms/step - loss: 2.0867e-05 - mse: 4.1735e-05 - val_loss: 0.0013 - val_mse: 0.0025
#
# Epoch 00008: val_loss did not improve from 0.00118
# Epoch 9/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.9922e-05 - mse: 3.9844e-05 - val_loss: 0.0010 - val_mse: 0.0020
#
# Epoch 00009: val_loss improved from 0.00118 to 0.00101, saving model to tmp\checkpointer.ckpt
# Epoch 10/50
# 150/150 [==============================] - 1s 7ms/step - loss: 1.9989e-05 - mse: 3.9978e-05 - val_loss: 0.0018 - val_mse: 0.0035
#
# Epoch 00010: val_loss did not improve from 0.00101
# Epoch 11/50
# 150/150 [==============================] - 1s 7ms/step - loss: 1.7869e-05 - mse: 3.5738e-05 - val_loss: 0.0016 - val_mse: 0.0031
#
# Epoch 00011: val_loss did not improve from 0.00101
# Epoch 12/50
# 150/150 [==============================] - 1s 7ms/step - loss: 1.6916e-05 - mse: 3.3831e-05 - val_loss: 0.0013 - val_mse: 0.0027
#
# Epoch 00012: val_loss did not improve from 0.00101
# Epoch 13/50
# 150/150 [==============================] - 1s 7ms/step - loss: 1.6758e-05 - mse: 3.3515e-05 - val_loss: 0.0012 - val_mse: 0.0025
#
# Epoch 00013: val_loss did not improve from 0.00101
# Epoch 14/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.6963e-05 - mse: 3.3927e-05 - val_loss: 6.3165e-04 - val_mse: 0.0013
#
# Epoch 00014: val_loss improved from 0.00101 to 0.00063, saving model to tmp\checkpointer.ckpt
# Epoch 15/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.8912e-05 - mse: 3.7825e-05 - val_loss: 0.0016 - val_mse: 0.0033
#
# Epoch 00015: val_loss did not improve from 0.00063
# Epoch 16/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.6255e-05 - mse: 3.2510e-05 - val_loss: 0.0012 - val_mse: 0.0025
#
# Epoch 00016: val_loss did not improve from 0.00063
# Epoch 17/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.5316e-05 - mse: 3.0631e-05 - val_loss: 0.0011 - val_mse: 0.0021
#
# Epoch 00017: val_loss did not improve from 0.00063
# Epoch 18/50
# 150/150 [==============================] - 1s 9ms/step - loss: 1.5832e-05 - mse: 3.1664e-05 - val_loss: 0.0011 - val_mse: 0.0023
#
# Epoch 00018: val_loss did not improve from 0.00063
# Epoch 19/50
# 150/150 [==============================] - 1s 9ms/step - loss: 1.5234e-05 - mse: 3.0468e-05 - val_loss: 5.6432e-04 - val_mse: 0.0011
#
# Epoch 00019: val_loss improved from 0.00063 to 0.00056, saving model to tmp\checkpointer.ckpt
# Epoch 20/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.4955e-05 - mse: 2.9910e-05 - val_loss: 0.0015 - val_mse: 0.0030
#
# Epoch 00020: val_loss did not improve from 0.00056
# Epoch 21/50
# 150/150 [==============================] - 1s 7ms/step - loss: 1.4316e-05 - mse: 2.8633e-05 - val_loss: 0.0010 - val_mse: 0.0021
#
# Epoch 00021: val_loss did not improve from 0.00056
# Epoch 22/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.4602e-05 - mse: 2.9203e-05 - val_loss: 4.7339e-04 - val_mse: 9.4679e-04
#
# Epoch 00022: val_loss improved from 0.00056 to 0.00047, saving model to tmp\checkpointer.ckpt
# Epoch 23/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.4492e-05 - mse: 2.8983e-05 - val_loss: 6.6179e-04 - val_mse: 0.0013
#
# Epoch 00023: val_loss did not improve from 0.00047
# Epoch 24/50
# 150/150 [==============================] - 1s 9ms/step - loss: 1.3548e-05 - mse: 2.7096e-05 - val_loss: 8.7337e-04 - val_mse: 0.0017
#
# Epoch 00024: val_loss did not improve from 0.00047
# Epoch 25/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.2677e-05 - mse: 2.5353e-05 - val_loss: 3.8951e-04 - val_mse: 7.7902e-04
#
# Epoch 00025: val_loss improved from 0.00047 to 0.00039, saving model to tmp\checkpointer.ckpt
# Epoch 26/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.2866e-05 - mse: 2.5732e-05 - val_loss: 0.0012 - val_mse: 0.0024
#
# Epoch 00026: val_loss did not improve from 0.00039
# Epoch 27/50
# 150/150 [==============================] - 1s 9ms/step - loss: 1.2337e-05 - mse: 2.4675e-05 - val_loss: 5.0958e-04 - val_mse: 0.0010
#
# Epoch 00027: val_loss did not improve from 0.00039
# Epoch 28/50
# 150/150 [==============================] - 2s 11ms/step - loss: 1.2222e-05 - mse: 2.4444e-05 - val_loss: 2.3186e-04 - val_mse: 4.6371e-04
#
# Epoch 00028: val_loss improved from 0.00039 to 0.00023, saving model to tmp\checkpointer.ckpt
# Epoch 29/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.2506e-05 - mse: 2.5011e-05 - val_loss: 2.1372e-04 - val_mse: 4.2744e-04
#
# Epoch 00029: val_loss improved from 0.00023 to 0.00021, saving model to tmp\checkpointer.ckpt
# Epoch 30/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.1307e-05 - mse: 2.2613e-05 - val_loss: 8.2197e-04 - val_mse: 0.0016
#
# Epoch 00030: val_loss did not improve from 0.00021
# Epoch 31/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.1769e-05 - mse: 2.3538e-05 - val_loss: 5.2369e-04 - val_mse: 0.0010
#
# Epoch 00031: val_loss did not improve from 0.00021
# Epoch 32/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.1483e-05 - mse: 2.2966e-05 - val_loss: 3.4894e-04 - val_mse: 6.9788e-04
#
# Epoch 00032: val_loss did not improve from 0.00021
# Epoch 33/50
# 150/150 [==============================] - 1s 9ms/step - loss: 1.1146e-05 - mse: 2.2293e-05 - val_loss: 4.7633e-04 - val_mse: 9.5266e-04
#
# Epoch 00033: val_loss did not improve from 0.00021
# Epoch 34/50
# 150/150 [==============================] - 1s 7ms/step - loss: 1.1060e-05 - mse: 2.2121e-05 - val_loss: 1.0260e-04 - val_mse: 2.0520e-04
#
# Epoch 00034: val_loss improved from 0.00021 to 0.00010, saving model to tmp\checkpointer.ckpt
# Epoch 35/50
# 150/150 [==============================] - 1s 9ms/step - loss: 1.0978e-05 - mse: 2.1956e-05 - val_loss: 1.3490e-04 - val_mse: 2.6979e-04
#
# Epoch 00035: val_loss did not improve from 0.00010
# Epoch 36/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.1148e-05 - mse: 2.2297e-05 - val_loss: 5.6933e-04 - val_mse: 0.0011
#
# Epoch 00036: val_loss did not improve from 0.00010
# Epoch 37/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.0928e-05 - mse: 2.1856e-05 - val_loss: 4.4961e-04 - val_mse: 8.9921e-04
#
# Epoch 00037: val_loss did not improve from 0.00010
# Epoch 38/50
# 150/150 [==============================] - 1s 8ms/step - loss: 1.0150e-05 - mse: 2.0301e-05 - val_loss: 1.7629e-04 - val_mse: 3.5258e-04
#
# Epoch 00038: val_loss did not improve from 0.00010
# Epoch 39/50
# 150/150 [==============================] - 1s 8ms/step - loss: 9.8813e-06 - mse: 1.9763e-05 - val_loss: 3.1686e-04 - val_mse: 6.3373e-04
#
# Epoch 00039: val_loss did not improve from 0.00010
# Epoch 40/50
# 150/150 [==============================] - 1s 9ms/step - loss: 1.0448e-05 - mse: 2.0897e-05 - val_loss: 2.5857e-04 - val_mse: 5.1715e-04
#
# Epoch 00040: val_loss did not improve from 0.00010
# Epoch 41/50
# 150/150 [==============================] - 1s 9ms/step - loss: 1.0139e-05 - mse: 2.0278e-05 - val_loss: 9.1443e-05 - val_mse: 1.8289e-04
#
# Epoch 00041: val_loss improved from 0.00010 to 0.00009, saving model to tmp\checkpointer.ckpt
# Epoch 42/50
# 150/150 [==============================] - 1s 8ms/step - loss: 9.7620e-06 - mse: 1.9524e-05 - val_loss: 2.4707e-04 - val_mse: 4.9414e-04
#
# Epoch 00042: val_loss did not improve from 0.00009
# Epoch 43/50
# 150/150 [==============================] - 1s 8ms/step - loss: 9.7599e-06 - mse: 1.9520e-05 - val_loss: 1.8281e-04 - val_mse: 3.6562e-04
#
# Epoch 00043: val_loss did not improve from 0.00009
# Epoch 44/50
# 150/150 [==============================] - 2s 10ms/step - loss: 9.3666e-06 - mse: 1.8733e-05 - val_loss: 2.9799e-04 - val_mse: 5.9599e-04
#
# Epoch 00044: val_loss did not improve from 0.00009
# Epoch 45/50
# 150/150 [==============================] - 1s 9ms/step - loss: 9.3799e-06 - mse: 1.8760e-05 - val_loss: 2.3687e-04 - val_mse: 4.7375e-04
#
# Epoch 00045: val_loss did not improve from 0.00009
# Epoch 46/50
# 150/150 [==============================] - 1s 8ms/step - loss: 8.9323e-06 - mse: 1.7865e-05 - val_loss: 2.2412e-04 - val_mse: 4.4824e-04
#
# Epoch 00046: val_loss did not improve from 0.00009
# Epoch 47/50
# 150/150 [==============================] - 1s 8ms/step - loss: 9.0839e-06 - mse: 1.8168e-05 - val_loss: 4.0291e-04 - val_mse: 8.0582e-04
#
# Epoch 00047: val_loss did not improve from 0.00009
# Epoch 48/50
# 150/150 [==============================] - 1s 7ms/step - loss: 8.6199e-06 - mse: 1.7240e-05 - val_loss: 3.4509e-04 - val_mse: 6.9017e-04
#
# Epoch 00048: val_loss did not improve from 0.00009
# Epoch 49/50
# 150/150 [==============================] - 1s 8ms/step - loss: 8.4499e-06 - mse: 1.6900e-05 - val_loss: 4.8280e-04 - val_mse: 9.6560e-04
#
# Epoch 00049: val_loss did not improve from 0.00009
# Epoch 50/50
# 150/150 [==============================] - 1s 8ms/step - loss: 8.6542e-06 - mse: 1.7308e-05 - val_loss: 4.0126e-04 - val_mse: 8.0253e-04
#
# Epoch 00050: val_loss did not improve from 0.00009

# %%
model.load_weights(filename)

# %%
pred = model.predict(test_data)

# %%
pred.shape
# Out:
# (1180, 1)

# %%
plt.figure(figsize=(12,9))
plt.plot(np.asarray(y_test)[20:], label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

acc = history.history['mse']
val_acc = history.history['val_mse']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, 'bo', label='Training loss')

plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend

plt.show()
